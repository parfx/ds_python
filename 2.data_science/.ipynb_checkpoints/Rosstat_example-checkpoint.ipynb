# %% [markdown]
# # Анализ данных из Росстат

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
# загрузка данных 
raw_stat_data = pd.read_excel('https://rosstat.gov.ru/storage/mediabank/cen-god.xls', skiprows=2, decimal=',').dropna()
raw_stat_data.head()
# Out:
#                          ПОКАЗАТЕЛИ    1991    1992     1993     1994  \
# 1  Говядина (кроме бескостного мяса)  15.54   221.5  2201.27  5186.28
# 2   Свинина (кроме бескостного мяса)  14.38     260  2672.81  6579.38
# 3     Куры охлажденные и мороженые1)  13.57  194.76  2238.98  5677.09
# 4                  Колбаса вареная2)     17     271   3351.3  8984.10
# 5           Консервы мясные3), 350 г   8.87   163.9  1165.48  2991.46
#
#       1995     1996     1997   1998   1999  ...    2010    2011    2012  \
# 1  12547.0  14137.0  15787.0  30.04  42.01  ...  197.64  234.49  248.47
# 2  15053.0  16810.0  19055.0  33.99  43.37  ...  198.35  210.89  220.09
# 3  11587.0  13815.0  16061.0  30.74  39.28  ...  105.14  103.57  117.26
# 4  20016.0  22859.0  26767.0  43.81  61.56  ...  235.96  270.28  288.23
# 5   6692.0   7375.0   7811.0  15.50  18.16  ...   63.79   70.35   75.22
#
#      2013    2014    2015    2016    2017    2018    2019
# ...

# %%
raw_stat_data.shape
# Out:
# (78, 30)

# %%
raw_stat_data.columns
# Out:
# Index([' ПОКАЗАТЕЛИ ',           1991,           1992,           1993,
#                  1994,           1995,           1996,           1997,
#                  1998,           1999,           2000,           2001,
#                  2002,           2003,           2004,           2005,
#                  2006,           2007,           2008,           2009,
#                  2010,           2011,           2012,           2013,
#                  2014,           2015,           2016,           2017,
#                  2018,           2019],
#       dtype='object')

# %%
raw_stat_data.columns = raw_stat_data.columns.astype('str')
raw_stat_data.columns
# Out:
# Index([' ПОКАЗАТЕЛИ ', '1991', '1992', '1993', '1994', '1995', '1996', '1997',
#        '1998', '1999', '2000', '2001', '2002', '2003', '2004', '2005', '2006',
#        '2007', '2008', '2009', '2010', '2011', '2012', '2013', '2014', '2015',
#        '2016', '2017', '2018', '2019'],
#       dtype='object')

# %%
# для удобства работы транспонируем таблицу
raw_stat_data = raw_stat_data.T
raw_stat_data.head()
# Out:
#                                              1   \
#  ПОКАЗАТЕЛИ   Говядина (кроме бескостного мяса)
# 1991                                      15.54
# 1992                                      221.5
# 1993                                    2201.27
# 1994                                    5186.28
#
#                                             2   \
#  ПОКАЗАТЕЛИ   Свинина (кроме бескостного мяса)
# 1991                                     14.38
# 1992                                       260
# 1993                                   2672.81
# 1994                                   6579.38
#
#                                           3                  4   \
#  ПОКАЗАТЕЛИ   Куры охлажденные и мороженые1)  Колбаса вареная2)
# 1991                                   13.57                 17
# 1992                                  194.76                271
# 1993                                 2238.98             3351.3
# ...

# %%
# в качестве ключей столбцов устанавливаем значения категории "Показатели"
raw_stat_data.columns = raw_stat_data.loc[' ПОКАЗАТЕЛИ ', :]
raw_stat_data.head()
# Out:
#  ПОКАЗАТЕЛИ   Говядина (кроме бескостного мяса)  \
#  ПОКАЗАТЕЛИ   Говядина (кроме бескостного мяса)
# 1991                                      15.54
# 1992                                      221.5
# 1993                                    2201.27
# 1994                                    5186.28
#
#  ПОКАЗАТЕЛИ   Свинина (кроме бескостного мяса)  \
#  ПОКАЗАТЕЛИ   Свинина (кроме бескостного мяса)
# 1991                                     14.38
# 1992                                       260
# 1993                                   2672.81
# 1994                                   6579.38
#
#  ПОКАЗАТЕЛИ   Куры охлажденные и мороженые1)  Колбаса вареная2)  \
#  ПОКАЗАТЕЛИ   Куры охлажденные и мороженые1)  Колбаса вареная2)
# 1991                                   13.57                 17
# 1992                                  194.76                271
# 1993                                 2238.98             3351.3
# ...

# %%
raw_stat_data.head(10)
# Out:
#  ПОКАЗАТЕЛИ   Говядина (кроме бескостного мяса)  \
#  ПОКАЗАТЕЛИ   Говядина (кроме бескостного мяса)
# 1991                                      15.54
# 1992                                      221.5
# 1993                                    2201.27
# 1994                                    5186.28
# 1995                                      12547
# 1996                                      14137
# 1997                                      15787
# 1998                                      30.04
# 1999                                      42.01
#
#  ПОКАЗАТЕЛИ   Свинина (кроме бескостного мяса)  \
#  ПОКАЗАТЕЛИ   Свинина (кроме бескостного мяса)
# 1991                                     14.38
# 1992                                       260
# 1993                                   2672.81
# 1994                                   6579.38
# 1995                                     15053
# 1996                                     16810
# 1997                                     19055
# ...

# %%
raw_stat_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 30 entries,  ПОКАЗАТЕЛИ  to 2019
# Data columns (total 78 columns):
#  #   Column                                                                                            Non-Null Count  Dtype
# ---  ------                                                                                            --------------  -----
#  0   Говядина (кроме бескостного мяса)                                                                 30 non-null     object
#  1   Свинина (кроме бескостного мяса)                                                                  30 non-null     object
#  2   Куры охлажденные и мороженые1)                                                                    30 non-null     object
#  3   Колбаса вареная2)                                                                                 30 non-null     object
# ...

# %%
raw_stat_data
# Out:
#  ПОКАЗАТЕЛИ   Говядина (кроме бескостного мяса)  \
#  ПОКАЗАТЕЛИ   Говядина (кроме бескостного мяса)
# 1991                                      15.54
# 1992                                      221.5
# 1993                                    2201.27
# 1994                                    5186.28
# 1995                                      12547
# 1996                                      14137
# 1997                                      15787
# 1998                                      30.04
# 1999                                      42.01
# 2000                                      52.72
# 2001                                      70.33
# 2002                                      72.56
# 2003                                       73.9
# 2004                                      93.41
# 2005                                     115.77
# 2006                                     131.67
# 2007                                     139.49
# ...

# %%
# срезаем из таблицы данные до 1998 года, так как до этого года была слишком большая инфляция
stat_data = raw_stat_data.loc['1998':, :]
stat_data.head()
# Out:
#  ПОКАЗАТЕЛИ  Говядина (кроме бескостного мяса)  \
# 1998                                     30.04
# 1999                                     42.01
# 2000                                     52.72
# 2001                                     70.33
# 2002                                     72.56
#
#  ПОКАЗАТЕЛИ  Свинина (кроме бескостного мяса) Куры охлажденные и мороженые1)  \
# 1998                                    33.99                          30.74
# 1999                                    43.37                          39.28
# 2000                                    58.45                           48.8
# 2001                                    79.22                          56.92
# 2002                                    80.98                          58.38
#
#  ПОКАЗАТЕЛИ  Колбаса вареная2) Консервы мясные3), 350 г  \
# 1998                     43.81                     15.5
# 1999                     61.56                    18.16
# ...

# %%
# символы "-" заменяем на 0 
stat_data = stat_data.replace('-', 0.0)
stat_data
# Out:
#  ПОКАЗАТЕЛИ  Говядина (кроме бескостного мяса)  \
# 1998                                     30.04
# 1999                                     42.01
# 2000                                     52.72
# 2001                                     70.33
# 2002                                     72.56
# 2003                                      73.9
# 2004                                     93.41
# 2005                                    115.77
# 2006                                    131.67
# 2007                                    139.49
# 2008                                    174.86
# 2009                                     185.6
# 2010                                    197.64
# 2011                                    234.49
# 2012                                    248.47
# 2013                                    244.55
# 2014                                    272.28
# 2015                                    314.94
# 2016                                    315.02
# ...

# %%
stat_data.values[:100]
# Out:
# array([[30.04, 33.99, 30.74, ..., 135.41, 41.9, 24.4],
#        [42.01, 43.37, 39.28, ..., 197.9, 52.67, 31.22],
#        [52.72, 58.45, 48.8, ..., 279.76, 62.97, 37.99],
#        ...,
#        [320.34, 255.87, 126.29, ..., 1869.65, 683.9, 370.24],
#        [330.58, 275.26, 151.27, ..., 1869.54, 724.61, 382.06],
#        ['350.05', '264.55', '143.13', ..., '1937.53', '780.86', '398.49']],
#       dtype=object)

# %%
# т.к тип некоторых данных является строковым, то нужно сконвертировать их в тип вещественных чисел
stat_data = stat_data.astype(np.float32)
stat_data.values[:100]
# Out:
# array([[  30.04,   33.99,   30.74, ...,  135.41,   41.9 ,   24.4 ],
#        [  42.01,   43.37,   39.28, ...,  197.9 ,   52.67,   31.22],
#        [  52.72,   58.45,   48.8 , ...,  279.76,   62.97,   37.99],
#        ...,
#        [ 320.34,  255.87,  126.29, ..., 1869.65,  683.9 ,  370.24],
#        [ 330.58,  275.26,  151.27, ..., 1869.54,  724.61,  382.06],
#        [ 350.05,  264.55,  143.13, ..., 1937.53,  780.86,  398.49]],
#       dtype=float32)

# %%
# "очищенный dataframe можно сохранить на диск в виде нового excel-файла"
#stat_data.to_excel('prices_stat_data_1998-2019.xlsx')

# %%
# смотрим на ключ столбцов
stat_data.columns
# Out:
# Index(['Говядина (кроме бескостного мяса)', 'Свинина (кроме бескостного мяса)',
#        'Куры охлажденные и мороженые1)', 'Колбаса вареная2)',
#        'Консервы мясные3), 350 г', 'Рыба мороженая неразделанная4)',
#        'Рыба соленая, маринованная, копченая ',
#        'Консервы рыбные натуральные и с добавлением масла,  350 г',
#        'Масло сливочное 5) ', 'Масло подсолнечное 6) ',
#        'Молоко питьевое цельное  пастеризованное 2,5-3,2% жирности7), за л',
#        'Сыры сычужные твердые и мягкие', 'Яйца куриные, за 10 шт.',
#        'Сахар-песок', 'Чай черный байховый', 'Мука пшеничная',
#        'Хлеб и булочные изделия из пшеничной муки высшего сорта',
#        'Рис шлифованный',
#        'Макаронные изделия из пшеничной муки высшего сорта8)', 'Картофель',
#        'Капуста белокочанная свежая', 'Лук репчатый', 'Яблоки',
#        'Водка крепостью 40% об.спирта и выше9), за л',
#        'Коньяк ординарный отечественный10), за  л',
# ...

# %%
# удаление лишних символов пробела (" ") из ключей столбцов
stat_data.columns = stat_data.columns.str.strip(" ")
stat_data.columns
# Out:
# Index(['Говядина (кроме бескостного мяса)', 'Свинина (кроме бескостного мяса)',
#        'Куры охлажденные и мороженые1)', 'Колбаса вареная2)',
#        'Консервы мясные3), 350 г', 'Рыба мороженая неразделанная4)',
#        'Рыба соленая, маринованная, копченая',
#        'Консервы рыбные натуральные и с добавлением масла,  350 г',
#        'Масло сливочное 5)', 'Масло подсолнечное 6)',
#        'Молоко питьевое цельное  пастеризованное 2,5-3,2% жирности7), за л',
#        'Сыры сычужные твердые и мягкие', 'Яйца куриные, за 10 шт.',
#        'Сахар-песок', 'Чай черный байховый', 'Мука пшеничная',
#        'Хлеб и булочные изделия из пшеничной муки высшего сорта',
#        'Рис шлифованный',
#        'Макаронные изделия из пшеничной муки высшего сорта8)', 'Картофель',
#        'Капуста белокочанная свежая', 'Лук репчатый', 'Яблоки',
#        'Водка крепостью 40% об.спирта и выше9), за л',
#        'Коньяк ординарный отечественный10), за  л',
# ...

# %%
stat_data['Общий анализ крови33)']
# Out:
# 1998     24.400000
# 1999     31.219999
# 2000     37.990002
# 2001     46.889999
# 2002     59.209999
# 2003     66.940002
# 2004     77.959999
# 2005     94.599998
# 2006    110.209999
# 2007    128.210007
# 2008    148.320007
# 2009    174.110001
# 2010    195.110001
# 2011    217.699997
# 2012    242.250000
# 2013    277.239990
# 2014    306.950012
# 2015    334.209991
# 2016    354.910004
# 2017    370.239990
# 2018    382.059998
# 2019    398.489990
# Name: Общий анализ крови33), dtype: float32

# %%
# сколько раз изменилась средняя цена на определенную категорию
stat_data.loc['2019', 'Общий анализ крови33)'] / stat_data.loc['1998', 'Общий анализ крови33)']
# Out:
# 16.331556

# %%
stat_data.loc['2019', 'Говядина (кроме бескостного мяса)'] / stat_data.loc['1998', 'Говядина (кроме бескостного мяса)']
# Out:
# 11.652796

# %%
# визуализация динамики средних цен по категориям

# извлечение данных
prices_1 = stat_data['Говядина (кроме бескостного мяса)']
prices_2 = stat_data['Консервы мясные3), 350 г']
prices_3 = stat_data['Гор.вода мес*чел']

# %%
# извлекаем года для временной шкалы, попутно конвертируя в целочисленный тип
years = stat_data.index.astype(int)
years
# Out:
# Int64Index([1998, 1999, 2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008,
#             2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019],
#            dtype='int64')

# %%
# строим график

plt.plot(years, prices_1, label='Говядина')
plt.plot(years, prices_2, label='Консервы (350 г)')
plt.plot(years, prices_3, label='Гор. вода (мес*чел)')

plt.legend()

plt.title('Динамика ср. цен с 1998 по 2019 гг')
plt.xlabel("годы")
plt.ylabel("ср. цены (руб)")

plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-34-c492da13df82> in <module>
#       2
#       3 plt.plot(years, prices_1, label='Говядина')
# ----> 4 plt.plot(years, prices_2, label='Консервы (350 г)')
#       5 plt.plot(years, prices_3, label='Гор. вода (мес*чел)')
#       6
#
# NameError: name 'prices_2' is not defined
